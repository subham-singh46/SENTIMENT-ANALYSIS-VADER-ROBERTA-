# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

import nltk

# %%
data= pd.read_csv("Reviews.csv")

# Downsampling the data as becuse the dataset is large

data= data.head(500)

# %%
data.shape
# Out:
# (500, 10)

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %% [markdown]
# # EDA

# %%
# Counting the values of distinct ratings

data['Score'].value_counts()
# Out:
# Score
# 5    339
# 4     70
# 3     37
# 1     36
# 2     18
# Name: count, dtype: int64

# %%
# Plotting 




ax= data["Score"].value_counts().sort_index().plot(kind='bar',title="Reviews by star",figsize=(10,5))

ax.set_xlabel('Review stars')
plt.show()

# %% [markdown]
# # NLTK

# %%
ex= data['Text'].iloc[50]

ex
# Out:
# "This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go."

# %%
tokens=nltk.word_tokenize(ex)
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
# Pos tags

tag=nltk.pos_tag(tokens)
tag[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
# Chunking

entities= nltk.chunk.ne_chunk(tag)
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# # VADER MODEL

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia= SentimentIntensityAnalyzer()

# %%
# checking polarity score for the selectd comment

sia.polarity_scores(ex)


#we can see that the overall score is -ve
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# running the polarity score on the entire dataset
res={}
for i, row in tqdm (data.iterrows(), total=len(data)):

    text=row['Text']
    myid=row['Id']
    res[myid]= sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
res
# Out:
# {1: {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.9441},
#  2: {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.5664},
#  3: {'neg': 0.091, 'neu': 0.754, 'pos': 0.155, 'compound': 0.8265},
#  4: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  5: {'neg': 0.0, 'neu': 0.552, 'pos': 0.448, 'compound': 0.9468},
#  6: {'neg': 0.029, 'neu': 0.809, 'pos': 0.163, 'compound': 0.883},
#  7: {'neg': 0.034, 'neu': 0.693, 'pos': 0.273, 'compound': 0.9346},
#  8: {'neg': 0.0, 'neu': 0.52, 'pos': 0.48, 'compound': 0.9487},
#  9: {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.6369},
#  10: {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.8313},
#  11: {'neg': 0.017, 'neu': 0.846, 'pos': 0.137, 'compound': 0.9746},
#  12: {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'compound': -0.7579},
#  13: {'neg': 0.031, 'neu': 0.923, 'pos': 0.046, 'compound': 0.296},
#  14: {'neg': 0.0, 'neu': 0.355, 'pos': 0.645, 'compound': 0.9466},
# ...

# %%
# Creating a dataframe of the results and merging it with the orignal data frame

vaders= pd.DataFrame(res).T

vaders= vaders.reset_index().rename(columns={'index':'Id'})
vaders= vaders.merge(data,how='left')

# %%
# Printing the merged dataframe

vaders
# Out:
#       Id    neg    neu    pos  compound   ProductId          UserId  \
# 0      1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1      2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2      3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3      4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4      5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
# ..   ...    ...    ...    ...       ...         ...             ...
# 495  496  0.000  0.554  0.446    0.9725  B000G6RYNE   APGAA43E3WPN7
# 496  497  0.059  0.799  0.142    0.7833  B000G6RYNE    ABR7HU5H1KNE
# 497  498  0.025  0.762  0.212    0.9848  B000G6RYNE   AJQD2WWJYOYFQ
# 498  499  0.041  0.904  0.055    0.1280  B000G6RYNE  A16YH487W9ZYO0
# 499  500  0.000  0.678  0.322    0.9811  B000G6RYNE   A83YQC1XOU4CS
#
#                          ProfileName  HelpfulnessNumerator  \
# 0                         delmartian                     1
# ...

# %% [markdown]
# # PLOTTING RESULTS

# %%
sns.barplot(data=vaders,x='Score',y='compound')
ax.set_title('Compound score of amazon reviews by stars')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.barplot(data=vaders, x='Score', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='Score', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='Score', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# # BERT MODEL
#
# ENCODER BASED MODEL BASED ON TRANSFORMERS
#
# REQUIRES DATA PRE-PROCESSING

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax
from collections.abc import Mapping,MutableMapping

# %%
MODEL= f"cardiffnlp/twitter-roberta-base-sentiment"

toknizer= AutoTokenizer.from_pretrained(MODEL)

model= AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
print(ex)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
# Vader results
sia.polarity_scores(ex)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
# Text encoding for Roberta
# Running our model on the text
# Storing scores in a dictionary

def polarity_scores_roberta(ex):

    encoded= toknizer(ex,return_tensors='pt')
    output= model(**encoded)

    scores= output[0][0].detach().numpy()
    scores=softmax(scores)
    scores_dict={
             'roberta_neg' :scores[0],
             'roberta_neu' :scores[1],
             'roberta_pos' :scores[2]
    }            

    return scores_dict

# %%
# Running both model for the reference comment (ex)
res={}

for i, row in tqdm(data.iterrows(),total=len(data)):
    text=row['Text']
    myid=row['Id']

    vader_result=sia.polarity_scores(text)

    roberta_result=polarity_scores_roberta(text)

    break
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %% [markdown]
# VADER RESULT

# %%
vader_result
# Out:
# {'neg': 0.0, 'neu': 0.695, 'pos': 0.305, 'compound': 0.9441}

# %% [markdown]
# Roberta result

# %%
roberta_result
# Out:
# {'roberta_neg': 0.009624231,
#  'roberta_neu': 0.049980372,
#  'roberta_pos': 0.94039536}

# %%
# Combining vader and roberta results

comb= {**vader_result, ** roberta_result}

# %%
# Running both the models for all of the data
res={}

for i, row in tqdm(data.iterrows(),total=len(data)):
   try: 
    
    text=row['Text']
    myid=row['Id']

    vader_result=sia.polarity_scores(text)

    roberta_result=polarity_scores_roberta(text)

    comb= {**vader_result, ** roberta_result}
    res[myid]=comb
   
   except RuntimeError:
    print(f'broke for id{myid}')
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# broke for id83
# broke for id187

# %%
# COMBINING RESULTS WITH THE ORIGNAL DATA FRAME

results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Id'})
results_df = results_df.merge(data, how='left')

# %%
results_df
# Out:
#       Id    neg    neu    pos  compound  roberta_neg  roberta_neu  \
# 0      1  0.000  0.695  0.305    0.9441     0.009624     0.049980
# 1      2  0.138  0.862  0.000   -0.5664     0.508986     0.452414
# 2      3  0.091  0.754  0.155    0.8265     0.003229     0.098067
# 3      4  0.000  1.000  0.000    0.0000     0.002295     0.090219
# 4      5  0.000  0.552  0.448    0.9468     0.001635     0.010302
# ..   ...    ...    ...    ...       ...          ...          ...
# 493  496  0.000  0.554  0.446    0.9725     0.001906     0.009862
# 494  497  0.059  0.799  0.142    0.7833     0.004415     0.034215
# 495  498  0.025  0.762  0.212    0.9848     0.006427     0.074537
# 496  499  0.041  0.904  0.055    0.1280     0.865614     0.119366
# 497  500  0.000  0.678  0.322    0.9811     0.002440     0.011327
#
#      roberta_pos   ProductId          UserId                      ProfileName  \
# 0       0.940395  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# ...

# %%
# PRINTING RESULT OF BOTH THE MODELS FOR A RANDOM REVIEW

print('VADER SCORE',results_df['compound'].iloc[51])

print('ROBERTA SCORE',results_df['roberta_pos'].iloc[51])
# Out:
# VADER SCORE 0.9194
# ROBERTA SCORE 0.9682822823524475

# %% [markdown]
# # COMPAIRING BOTH RESULTS

# %%
results_df.columns
# Out:
# Index(['Id', 'neg', 'neu', 'pos', 'compound', 'roberta_neg', 'roberta_neu',
#        'roberta_pos', 'ProductId', 'UserId', 'ProfileName',
#        'HelpfulnessNumerator', 'HelpfulnessDenominator', 'Score', 'Time',
#        'Summary', 'Text'],
#       dtype='object')

# %%
# Pair plot

sns.pairplot(data=results_df,vars=[ 'neg', 'neu', 'compound',  'roberta_neg', 'roberta_neu',
       'roberta_pos'],hue='Score',palette='tab10')
